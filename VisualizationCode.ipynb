# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/NumericalAnalysis2020/blob/master/VisualizationCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Sample visualization - use of matplotlib graphics**

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 150, where=(ys > 150), facecolor='blue', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# # **Plot histogram filled with random numbers**

# %%
num_bins = 50

z = np.random.randn(1000)

print("Shape of z: ",z.shape," first 5 values:",z[:5])
6
# the histogram of the data
n, bins, patches = plt.hist(z, num_bins, facecolor='green',  density=True)

plt.title("Histogram Visualization")
plt.xlabel('X-values')
plt.ylabel('Entries')

plt.text(1, .4, r'Random numbers')
plt.xlim(-3, 3)
#plt.ylim(0, 0.5)
plt.grid(True)

plt.show()
# Out:
# Shape of z:  (1000,)  first 5 values: [ 0.99305874 -0.54823596 -0.47415122 -0.13585975  2.66733579]

# %% [markdown]
# # **Draw a function**
# # Working with multiple figures and axes
#
# MATLAB, and pyplot, have the concept of the current figure and the current axes. All plotting commands apply to the current axes.
# Below is a script to create two subplots.

# %%
def f1(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

def f2(t):
    return np.cos(2*np.pi*t)
   

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()
plt.subplot(211)
plt.plot(t1, f1(t1), 'bo', t2, f1(t2), 'k')

plt.subplot(212)
plt.plot(t2, f2(t2), 'r--')
plt.show()
